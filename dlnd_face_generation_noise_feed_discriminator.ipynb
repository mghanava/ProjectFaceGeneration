# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
# !unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/stable/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    """

    # TODO: Implement function and return a dataloader
    
    transform = transforms.Compose([
        transforms.Resize(size=(image_size, img_size)),
        transforms.ToTensor()
    ])
    
    data = datasets.ImageFolder(root=data_dir, transform=transform)
    data_loader = torch.utils.data.DataLoader(dataset=data, batch_size=batch_size, shuffle=True, pin_memory=True)
    
    return data_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 128
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %%
print("Number of train loader images: {}".format(len(celeba_train_loader.dataset)))
print("Number of batches: {}".format(len(celeba_train_loader)))
# Out:
# Number of train loader images: 89931
# Number of batches: 703

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# make sure images are scaled to (0, 1)
images = (images - images.min()) / (images.max() - images.min())

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x in any scale and returns that image, 
    scaled with a feature_range of pixel values from -1 to 1.'''
    # scale to feature_range and return scaled x
    x = 2 * (x - x.min()) / (x.max() - x.min()) - 1
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-1.)
# Max:  tensor(1.)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F
import collections

# %%
class Discriminator(nn.Module):

    def __init__(self, conv_dim=32):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        
        ## Define downsampler
        self.features = nn.Sequential(collections.OrderedDict([
            ('conv1', nn.Conv2d(in_channels=3, out_channels=conv_dim*4, 
                                kernel_size=4, stride=2, padding=1, bias=True)),
            ('leakyrelu1', nn.LeakyReLU(negative_slope=0.2, inplace=True)),         
            ('conv2', nn.Conv2d(in_channels=conv_dim*4, out_channels=conv_dim*8, 
                                kernel_size=4, stride=2, padding=1, bias=False)),
            ('batchnorm1', nn.BatchNorm2d(num_features=conv_dim*8)),
            ('leakyrelu2', nn.LeakyReLU(negative_slope=0.2, inplace=True)),
            ('conv3', nn.Conv2d(in_channels=conv_dim*8, out_channels=conv_dim*16, 
                                kernel_size=4, stride=2, padding=1, bias=False)),
            ('batchnorm2', nn.BatchNorm2d(num_features=conv_dim*16)),
            ('leakyrelu3', nn.LeakyReLU(negative_slope=0.2, inplace=True)) 
        ]))
        
        self.classifier = nn.Sequential(collections.OrderedDict([           
            ('fc', nn.Linear(in_features=conv_dim*16*4*4, out_features=1, bias=True))
        ]))
      
   
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        
        x = self.features(x)
        x = x.view(-1, self.conv_dim*16*4*4) # flatten feature vector prior to entering classifier
        x = self.classifier(x)
        
        return x
        
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim=32):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        
        self.conv_dim = conv_dim

        ## Define layers of a CNN
        self.vectorizer = nn.Sequential(collections.OrderedDict([           
            ('fc', nn.Linear(in_features=z_size, out_features=conv_dim*16*4*4, bias=True))
        ]))
        
        self.upsampler = nn.Sequential(collections.OrderedDict([
            ('transpose_conv1', nn.ConvTranspose2d(in_channels=conv_dim*16, out_channels=conv_dim*8, 
                                kernel_size=4, stride=2, padding=1, bias=False)),
            ('batchnorm1', nn.BatchNorm2d(num_features=conv_dim*8)),
            ('relu1', nn.ReLU(inplace=True)),         
            ('transpose_conv2', nn.ConvTranspose2d(in_channels=conv_dim*8, out_channels=conv_dim*4, 
                                kernel_size=4, stride=2, padding=1, bias=False)),
            ('batchnorm2', nn.BatchNorm2d(num_features=conv_dim*4)),
            ('relu2', nn.ReLU(inplace=True)),
            ('transpose_conv3', nn.ConvTranspose2d(in_channels=conv_dim*4, out_channels=3, 
                                kernel_size=4, stride=2, padding=1, bias=True)),
            ('tanh', nn.Tanh())  
        ]))
        
    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        x = self.vectorizer(x)
        x = x.view(-1, self.conv_dim*16, 4, 4) 
        x = self.upsampler(x)
        
        return x

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    
    # TODO: Apply initial weights to convolutional and linear layers
    if isinstance(m, nn.Conv2d):
        nn.init.normal_(m.weight, mean=0.0, std=0.02)
    if isinstance(m, nn.Linear):
        nn.init.normal_(m.weight, mean=0.0, std=0.02)

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 128

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (features): Sequential(
#     (conv1): Conv2d(3, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (leakyrelu1): LeakyReLU(negative_slope=0.2, inplace)
#     (conv2): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batchnorm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leakyrelu2): LeakyReLU(negative_slope=0.2, inplace)
#     (conv3): Conv2d(256, 512, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batchnorm2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (leakyrelu3): LeakyReLU(negative_slope=0.2, inplace)
#   )
#   (classifier): Sequential(
#     (fc): Linear(in_features=8192, out_features=1, bias=True)
#   )
# )
#
# Generator(
#   (vectorizer): Sequential(
#     (fc): Linear(in_features=128, out_features=8192, bias=True)
#   )
#   (upsampler): Sequential(
#     (transpose_conv1): ConvTranspose2d(512, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batchnorm1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu1): ReLU(inplace)
#     (transpose_conv2): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (batchnorm2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu2): ReLU(inplace)
#     (transpose_conv3): ConvTranspose2d(128, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1))
#     (tanh): Tanh()
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    if smooth:
        labels = torch.ones(batch_size) * 0.9
    else:
        labels = torch.ones(batch_size)
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size)
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim

# params
lr = 0.0002
beta1=0.5
beta2=0.999 # default value

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, (beta1, beta2))
g_optimizer = optim.Adam(G.parameters(), lr, (beta1, beta2))

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %%
def slerp(interpol_param, first_point, last_point):
    
    
    first_point_norm = first_point/torch.norm(first_point, dim=1, keepdim=True)
    last_point_norm = last_point/torch.norm(last_point, dim=1, keepdim=True)
    omega = torch.acos((first_point_norm*last_point_norm).sum(1))
    so = torch.sin(omega)
    
    if 0 in so:
        linear_interpol = (1.0-interpol_param) * first_point + interpol_param * last_point # L'Hopital's rule/LERP
        return linear_interpol
    
    spheric_linear_interpol = (torch.sin((1.0-interpol_param)*omega)/so).unsqueeze(1)*first_point + (torch.sin(interpol_param*omega)/so).unsqueeze(1) * last_point
    
    return spheric_linear_interpol

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    # each sample in the mini-batch is a point on the arc 
    z_start_unscaled = torch.randn(sample_size, z_size)
    z_end_unscaled = torch.randn(sample_size, z_size)
    z_interpol_unscaled = slerp(np.random.uniform(0, 1), z_start_unscaled, z_end_unscaled)

    temp = []
    for img in range(sample_size):
        img_scaled = scale(z_interpol_unscaled[img]).unsqueeze(0)   
        temp.append(img_scaled)
    fixed_z = torch.cat(temp, dim=0)  
#     fixed_z = torch.FloatTensor(size=(sample_size, z_size)).uniform_(-1, 1) 
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
#             real_images = scale(real_images)

            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            # Train on real images from train loader
            d_optimizer.zero_grad()

            ## add random noise to the input images and scale it to be in (-1, 1)
            real_images = real_images + noise_factor * torch.randn(*real_images.shape)
            real_images = scale(real_images)
            
            if train_on_gpu:
                real_images = real_images.cuda()
            
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            # Train on randomly generated fake images 
            z_start_unscaled = torch.randn(batch_size, z_size)
            z_end_unscaled = torch.randn(batch_size, z_size)
            z_interpol_unscaled = slerp(np.random.uniform(0, 1), z_start_unscaled, z_end_unscaled)

            temp = []
            for img in range(batch_size):
                img_scaled = scale(z_interpol_unscaled[img]).unsqueeze(0)   
                temp.append(img_scaled)
            z = torch.cat(temp, dim=0)                       
#             z =  torch.FloatTensor(size=(batch_size, z_size)).uniform_(-1, 1)           
            if train_on_gpu:
                z = z.cuda()           
            fake_images = G(z)
            
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            d_loss = d_real_loss + d_fake_loss
            
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            # Train with fake images and flipped labels
        
            # Generate fake images
            z_start_unscaled = torch.randn(batch_size, z_size)
            z_end_unscaled = torch.randn(batch_size, z_size)
            z_interpol_unscaled = slerp(np.random.uniform(0, 1), z_start_unscaled, z_end_unscaled)

            temp = []
            for img in range(batch_size):
                img_scaled = scale(z_interpol_unscaled[img]).unsqueeze(0)   
                temp.append(img_scaled)
            z = torch.cat(temp, dim=0) 
#             z =  torch.FloatTensor(size=(batch_size, z_size)).uniform_(-1, 1)  
            if train_on_gpu:
                z = z.cuda()
            fake_images = G(z)
        
            # Compute the discriminator losses on fake images 
            # using flipped labels!
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake) # use real loss to flip labels
        
            # perform backprop
            g_loss.backward()
            g_optimizer.step()            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
import signal
 
from contextlib import contextmanager
 
import requests
 
 
DELAY = INTERVAL = 4 * 60  # interval time in seconds
MIN_DELAY = MIN_INTERVAL = 2 * 60
KEEPALIVE_URL = "https://nebula.udacity.com/api/v1/remote/keep-alive"
TOKEN_URL = "http://metadata.google.internal/computeMetadata/v1/instance/attributes/keep_alive_token"
TOKEN_HEADERS = {"Metadata-Flavor":"Google"}
 
 
def _request_handler(headers):
    def _handler(signum, frame):
        requests.request("POST", KEEPALIVE_URL, headers=headers)
    return _handler
 
 
@contextmanager
def active_session(delay=DELAY, interval=INTERVAL):
    """
    Example:
 
    from workspace_utils import active_session
 
    with active_session():
        # do long-running work here
    """
    token = requests.request("GET", TOKEN_URL, headers=TOKEN_HEADERS).text
    headers = {'Authorization': "STAR " + token}
    delay = max(delay, MIN_DELAY)
    interval = max(interval, MIN_INTERVAL)
    original_handler = signal.getsignal(signal.SIGALRM)
    try:
        signal.signal(signal.SIGALRM, _request_handler(headers))
        signal.setitimer(signal.ITIMER_REAL, delay, interval)
        yield
    finally:
        signal.signal(signal.SIGALRM, original_handler)
        signal.setitimer(signal.ITIMER_REAL, 0)

# %%
# set number of epochs 
n_epochs =30
noise_factor = 0.5


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
with active_session():
    losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   30] | d_loss: 1.6155 | g_loss: 0.2503
# Epoch [    1/   30] | d_loss: 0.9253 | g_loss: 3.5338
# Epoch [    1/   30] | d_loss: 0.5432 | g_loss: 3.4723
# Epoch [    1/   30] | d_loss: 0.5063 | g_loss: 2.3346
# Epoch [    1/   30] | d_loss: 0.4393 | g_loss: 3.6296
# Epoch [    1/   30] | d_loss: 0.3374 | g_loss: 3.1755
# Epoch [    1/   30] | d_loss: 0.3481 | g_loss: 4.0286
# Epoch [    1/   30] | d_loss: 0.6691 | g_loss: 5.3813
# Epoch [    1/   30] | d_loss: 0.4200 | g_loss: 3.8950
# Epoch [    1/   30] | d_loss: 0.5613 | g_loss: 4.9834
# Epoch [    1/   30] | d_loss: 0.4281 | g_loss: 3.9198
# Epoch [    1/   30] | d_loss: 0.6486 | g_loss: 5.2575
# Epoch [    1/   30] | d_loss: 0.8245 | g_loss: 7.2697
# Epoch [    1/   30] | d_loss: 0.7148 | g_loss: 3.3597
# Epoch [    1/   30] | d_loss: 0.4479 | g_loss: 4.2629
# Epoch [    2/   30] | d_loss: 0.5094 | g_loss: 2.9757
# Epoch [    2/   30] | d_loss: 0.6668 | g_loss: 4.3885
# Epoch [    2/   30] | d_loss: 0.5579 | g_loss: 3.9319
# Epoch [    2/   30] | d_loss: 0.6160 | g_loss: 3.2971
# Epoch [    2/   30] | d_loss: 0.7567 | g_loss: 4.5783
# Epoch [    2/   30] | d_loss: 0.9451 | g_loss: 5.4243
# Epoch [    2/   30] | d_loss: 0.8228 | g_loss: 4.6619
# Epoch [    2/   30] | d_loss: 0.6451 | g_loss: 3.6158
# Epoch [    2/   30] | d_loss: 0.8316 | g_loss: 2.9717
# Epoch [    2/   30] | d_loss: 0.7310 | g_loss: 2.4623
# Epoch [    2/   30] | d_loss: 0.7356 | g_loss: 2.3003
# Epoch [    2/   30] | d_loss: 0.9151 | g_loss: 3.3421
# Epoch [    2/   30] | d_loss: 1.0107 | g_loss: 1.6627
# Epoch [    2/   30] | d_loss: 0.8218 | g_loss: 2.7429
# Epoch [    2/   30] | d_loss: 0.8979 | g_loss: 2.3586
# Epoch [    3/   30] | d_loss: 0.9363 | g_loss: 2.6554
# Epoch [    3/   30] | d_loss: 1.0148 | g_loss: 1.7396
# Epoch [    3/   30] | d_loss: 0.9588 | g_loss: 1.9955
# Epoch [    3/   30] | d_loss: 0.9372 | g_loss: 1.9688
# Epoch [    3/   30] | d_loss: 1.0324 | g_loss: 1.8686
# Epoch [    3/   30] | d_loss: 1.0186 | g_loss: 1.7054
# Epoch [    3/   30] | d_loss: 1.2142 | g_loss: 1.0555
# Epoch [    3/   30] | d_loss: 1.0259 | g_loss: 1.4882
# Epoch [    3/   30] | d_loss: 1.1204 | g_loss: 1.6977
# Epoch [    3/   30] | d_loss: 1.1975 | g_loss: 1.1555
# Epoch [    3/   30] | d_loss: 1.3400 | g_loss: 1.2191
# Epoch [    3/   30] | d_loss: 1.0242 | g_loss: 1.3828
# Epoch [    3/   30] | d_loss: 1.1787 | g_loss: 1.6820
# Epoch [    3/   30] | d_loss: 1.2050 | g_loss: 1.4424
# Epoch [    3/   30] | d_loss: 1.2625 | g_loss: 1.3886
# Epoch [    4/   30] | d_loss: 1.2158 | g_loss: 1.2518
# Epoch [    4/   30] | d_loss: 1.6587 | g_loss: 0.6996
# Epoch [    4/   30] | d_loss: 1.0711 | g_loss: 1.4324
# Epoch [    4/   30] | d_loss: 1.1868 | g_loss: 1.2487
# Epoch [    4/   30] | d_loss: 1.3782 | g_loss: 1.3598
# Epoch [    4/   30] | d_loss: 1.0759 | g_loss: 1.0497
# Epoch [    4/   30] | d_loss: 1.1904 | g_loss: 1.5562
# Epoch [    4/   30] | d_loss: 1.5564 | g_loss: 0.6321
# Epoch [    4/   30] | d_loss: 1.2765 | g_loss: 0.9199
# Epoch [    4/   30] | d_loss: 1.2492 | g_loss: 1.3063
# Epoch [    4/   30] | d_loss: 1.2551 | g_loss: 0.8365
# Epoch [    4/   30] | d_loss: 1.2792 | g_loss: 1.0790
# Epoch [    4/   30] | d_loss: 1.0946 | g_loss: 1.2047
# Epoch [    4/   30] | d_loss: 1.2154 | g_loss: 0.9304
# Epoch [    4/   30] | d_loss: 1.3214 | g_loss: 1.2231
# Epoch [    5/   30] | d_loss: 1.5604 | g_loss: 0.4658
# Epoch [    5/   30] | d_loss: 1.3988 | g_loss: 1.0608
# Epoch [    5/   30] | d_loss: 1.3937 | g_loss: 1.4034
# Epoch [    5/   30] | d_loss: 1.4139 | g_loss: 0.7478
# Epoch [    5/   30] | d_loss: 1.5644 | g_loss: 0.5761
# Epoch [    5/   30] | d_loss: 1.3774 | g_loss: 0.9330
# Epoch [    5/   30] | d_loss: 1.3883 | g_loss: 0.8477
# Epoch [    5/   30] | d_loss: 1.2588 | g_loss: 0.8937
# Epoch [    5/   30] | d_loss: 1.3735 | g_loss: 0.9439
# Epoch [    5/   30] | d_loss: 1.1858 | g_loss: 1.1724
# Epoch [    5/   30] | d_loss: 1.3524 | g_loss: 1.3366
# Epoch [    5/   30] | d_loss: 1.5421 | g_loss: 1.1337
# Epoch [    5/   30] | d_loss: 1.2971 | g_loss: 0.8353
# Epoch [    5/   30] | d_loss: 1.4293 | g_loss: 0.8323
# Epoch [    5/   30] | d_loss: 1.2574 | g_loss: 0.8093
# Epoch [    6/   30] | d_loss: 1.3469 | g_loss: 0.8475
# Epoch [    6/   30] | d_loss: 1.4131 | g_loss: 0.9534
# Epoch [    6/   30] | d_loss: 1.3263 | g_loss: 0.7266
# Epoch [    6/   30] | d_loss: 1.3157 | g_loss: 0.6151
# Epoch [    6/   30] | d_loss: 1.3897 | g_loss: 0.7307
# Epoch [    6/   30] | d_loss: 1.3491 | g_loss: 0.7307
# Epoch [    6/   30] | d_loss: 1.4735 | g_loss: 0.7199
# Epoch [    6/   30] | d_loss: 1.5660 | g_loss: 0.6306
# Epoch [    6/   30] | d_loss: 1.3849 | g_loss: 0.8229
# Epoch [    6/   30] | d_loss: 1.2524 | g_loss: 0.8413
# Epoch [    6/   30] | d_loss: 1.4145 | g_loss: 0.7021
# Epoch [    6/   30] | d_loss: 1.3408 | g_loss: 0.7434
# Epoch [    6/   30] | d_loss: 1.3013 | g_loss: 0.8408
# Epoch [    6/   30] | d_loss: 1.3768 | g_loss: 0.7215
# Epoch [    6/   30] | d_loss: 1.4494 | g_loss: 0.8414
# Epoch [    7/   30] | d_loss: 1.3262 | g_loss: 0.9023
# Epoch [    7/   30] | d_loss: 1.3431 | g_loss: 0.7561
# Epoch [    7/   30] | d_loss: 1.1952 | g_loss: 1.1672
# Epoch [    7/   30] | d_loss: 1.3522 | g_loss: 0.7064
# Epoch [    7/   30] | d_loss: 1.2789 | g_loss: 0.7972
# Epoch [    7/   30] | d_loss: 1.2216 | g_loss: 0.8268
# Epoch [    7/   30] | d_loss: 1.4079 | g_loss: 0.7680
# Epoch [    7/   30] | d_loss: 1.3917 | g_loss: 0.7010
# Epoch [    7/   30] | d_loss: 1.3640 | g_loss: 0.7648
# Epoch [    7/   30] | d_loss: 1.3858 | g_loss: 0.8421
# Epoch [    7/   30] | d_loss: 1.4148 | g_loss: 0.7402
# Epoch [    7/   30] | d_loss: 1.3954 | g_loss: 0.9347
# Epoch [    7/   30] | d_loss: 1.3840 | g_loss: 0.7560
# Epoch [    7/   30] | d_loss: 1.3974 | g_loss: 0.8468
# Epoch [    7/   30] | d_loss: 1.3751 | g_loss: 0.7365
# Epoch [    8/   30] | d_loss: 1.3656 | g_loss: 0.9460
# Epoch [    8/   30] | d_loss: 1.3636 | g_loss: 0.7482
# Epoch [    8/   30] | d_loss: 1.3268 | g_loss: 0.7746
# Epoch [    8/   30] | d_loss: 1.4065 | g_loss: 0.7373
# Epoch [    8/   30] | d_loss: 1.3602 | g_loss: 0.8370
# Epoch [    8/   30] | d_loss: 1.3801 | g_loss: 0.7824
# Epoch [    8/   30] | d_loss: 1.3847 | g_loss: 0.7204
# Epoch [    8/   30] | d_loss: 1.4193 | g_loss: 0.6639
# Epoch [    8/   30] | d_loss: 1.3956 | g_loss: 0.5589
# Epoch [    8/   30] | d_loss: 1.3119 | g_loss: 0.7294
# Epoch [    8/   30] | d_loss: 1.4041 | g_loss: 0.5918
# Epoch [    8/   30] | d_loss: 1.3720 | g_loss: 0.8949
# Epoch [    8/   30] | d_loss: 1.3645 | g_loss: 0.8494
# Epoch [    8/   30] | d_loss: 1.4400 | g_loss: 0.5710
# Epoch [    8/   30] | d_loss: 1.3989 | g_loss: 0.7747
# Epoch [    9/   30] | d_loss: 1.4208 | g_loss: 0.7084
# Epoch [    9/   30] | d_loss: 1.3924 | g_loss: 0.8254
# Epoch [    9/   30] | d_loss: 1.3859 | g_loss: 0.9327
# Epoch [    9/   30] | d_loss: 1.3643 | g_loss: 0.7697
# Epoch [    9/   30] | d_loss: 1.4234 | g_loss: 0.6402
# Epoch [    9/   30] | d_loss: 1.4750 | g_loss: 0.7092
# Epoch [    9/   30] | d_loss: 1.3722 | g_loss: 0.7158
# Epoch [    9/   30] | d_loss: 1.3767 | g_loss: 0.9197
# Epoch [    9/   30] | d_loss: 1.3760 | g_loss: 0.8166
# Epoch [    9/   30] | d_loss: 1.3975 | g_loss: 0.7956
# Epoch [    9/   30] | d_loss: 1.3948 | g_loss: 0.7614
# Epoch [    9/   30] | d_loss: 1.3832 | g_loss: 0.5505
# Epoch [    9/   30] | d_loss: 1.4229 | g_loss: 0.8077
# Epoch [    9/   30] | d_loss: 1.4300 | g_loss: 0.7111
# Epoch [    9/   30] | d_loss: 1.3976 | g_loss: 0.7680
# Epoch [   10/   30] | d_loss: 1.4013 | g_loss: 0.5240
# Epoch [   10/   30] | d_loss: 1.3764 | g_loss: 0.7283
# Epoch [   10/   30] | d_loss: 1.4057 | g_loss: 0.9246
# Epoch [   10/   30] | d_loss: 1.3863 | g_loss: 0.7383
# Epoch [   10/   30] | d_loss: 1.3689 | g_loss: 0.7617
# Epoch [   10/   30] | d_loss: 1.3729 | g_loss: 0.6466
# Epoch [   10/   30] | d_loss: 1.3793 | g_loss: 0.7628
# Epoch [   10/   30] | d_loss: 1.4128 | g_loss: 0.6910
# Epoch [   10/   30] | d_loss: 1.3627 | g_loss: 0.6833
# Epoch [   10/   30] | d_loss: 1.3857 | g_loss: 0.7341
# Epoch [   10/   30] | d_loss: 1.4196 | g_loss: 0.6607
# Epoch [   10/   30] | d_loss: 1.3456 | g_loss: 0.7583
# Epoch [   10/   30] | d_loss: 1.4045 | g_loss: 0.6967
# Epoch [   10/   30] | d_loss: 1.3680 | g_loss: 0.7709
# Epoch [   10/   30] | d_loss: 1.3878 | g_loss: 0.7094
# Epoch [   11/   30] | d_loss: 1.3812 | g_loss: 0.7641
# Epoch [   11/   30] | d_loss: 1.4165 | g_loss: 0.7975
# Epoch [   11/   30] | d_loss: 1.3736 | g_loss: 0.7308
# Epoch [   11/   30] | d_loss: 1.3928 | g_loss: 0.8115
# Epoch [   11/   30] | d_loss: 1.3552 | g_loss: 0.5474
# Epoch [   11/   30] | d_loss: 1.3892 | g_loss: 0.7235
# Epoch [   11/   30] | d_loss: 1.3768 | g_loss: 0.6803
# Epoch [   11/   30] | d_loss: 1.3885 | g_loss: 0.6983
# Epoch [   11/   30] | d_loss: 1.4073 | g_loss: 0.6950
# Epoch [   11/   30] | d_loss: 1.3775 | g_loss: 0.8521
# Epoch [   11/   30] | d_loss: 1.3832 | g_loss: 0.7589
# Epoch [   11/   30] | d_loss: 1.3846 | g_loss: 0.6919
# Epoch [   11/   30] | d_loss: 1.4304 | g_loss: 0.7028
# Epoch [   11/   30] | d_loss: 1.4698 | g_loss: 0.4710
# Epoch [   11/   30] | d_loss: 1.3794 | g_loss: 0.5579
# Epoch [   12/   30] | d_loss: 1.4927 | g_loss: 1.0963
# Epoch [   12/   30] | d_loss: 1.3926 | g_loss: 0.4786
# Epoch [   12/   30] | d_loss: 1.4452 | g_loss: 0.7201
# Epoch [   12/   30] | d_loss: 1.4348 | g_loss: 0.6376
# Epoch [   12/   30] | d_loss: 1.4864 | g_loss: 0.9064
# Epoch [   12/   30] | d_loss: 1.4073 | g_loss: 0.5665
# Epoch [   12/   30] | d_loss: 1.3899 | g_loss: 0.7832
# Epoch [   12/   30] | d_loss: 1.3670 | g_loss: 0.7099
# Epoch [   12/   30] | d_loss: 1.3995 | g_loss: 0.7156
# Epoch [   12/   30] | d_loss: 1.3990 | g_loss: 0.7036
# Epoch [   12/   30] | d_loss: 1.4061 | g_loss: 0.7033
# Epoch [   12/   30] | d_loss: 1.4099 | g_loss: 0.7114
# Epoch [   12/   30] | d_loss: 1.4145 | g_loss: 0.6675
# Epoch [   12/   30] | d_loss: 1.3793 | g_loss: 0.7029
# Epoch [   12/   30] | d_loss: 1.4344 | g_loss: 0.6893
# Epoch [   13/   30] | d_loss: 1.3842 | g_loss: 0.7518
# Epoch [   13/   30] | d_loss: 1.3888 | g_loss: 0.7067
# Epoch [   13/   30] | d_loss: 1.3840 | g_loss: 0.7283
# Epoch [   13/   30] | d_loss: 1.3796 | g_loss: 0.6908
# Epoch [   13/   30] | d_loss: 1.3830 | g_loss: 0.7569
# Epoch [   13/   30] | d_loss: 1.4082 | g_loss: 0.7540
# Epoch [   13/   30] | d_loss: 1.3949 | g_loss: 0.7300
# Epoch [   13/   30] | d_loss: 1.3899 | g_loss: 0.7126
# Epoch [   13/   30] | d_loss: 1.4046 | g_loss: 0.7148
# Epoch [   13/   30] | d_loss: 1.3842 | g_loss: 0.7319
# Epoch [   13/   30] | d_loss: 1.3871 | g_loss: 0.7471
# Epoch [   13/   30] | d_loss: 1.3836 | g_loss: 0.7258
# Epoch [   13/   30] | d_loss: 1.3723 | g_loss: 0.7379
# Epoch [   13/   30] | d_loss: 1.4157 | g_loss: 0.7295
# Epoch [   13/   30] | d_loss: 1.4763 | g_loss: 0.7690
# Epoch [   14/   30] | d_loss: 1.4116 | g_loss: 0.7287
# Epoch [   14/   30] | d_loss: 1.4258 | g_loss: 0.9650
# Epoch [   14/   30] | d_loss: 1.3831 | g_loss: 0.6945
# Epoch [   14/   30] | d_loss: 1.3873 | g_loss: 0.7277
# Epoch [   14/   30] | d_loss: 1.3924 | g_loss: 0.7174
# Epoch [   14/   30] | d_loss: 1.3855 | g_loss: 0.7175
# Epoch [   14/   30] | d_loss: 1.3922 | g_loss: 0.6704
# Epoch [   14/   30] | d_loss: 1.4069 | g_loss: 0.6491
# Epoch [   14/   30] | d_loss: 1.4202 | g_loss: 0.8025
# Epoch [   14/   30] | d_loss: 1.4248 | g_loss: 0.6481
# Epoch [   14/   30] | d_loss: 1.4132 | g_loss: 0.4989
# Epoch [   14/   30] | d_loss: 1.4238 | g_loss: 0.5285
# Epoch [   14/   30] | d_loss: 1.3942 | g_loss: 0.6916
# Epoch [   14/   30] | d_loss: 1.4405 | g_loss: 0.9779
# Epoch [   14/   30] | d_loss: 1.4117 | g_loss: 0.9481
# Epoch [   15/   30] | d_loss: 1.4101 | g_loss: 0.5478
# Epoch [   15/   30] | d_loss: 1.3895 | g_loss: 0.7417
# Epoch [   15/   30] | d_loss: 1.4323 | g_loss: 0.8731
# Epoch [   15/   30] | d_loss: 1.3913 | g_loss: 0.6990
# Epoch [   15/   30] | d_loss: 1.3972 | g_loss: 0.7006
# Epoch [   15/   30] | d_loss: 1.3874 | g_loss: 0.7096
# Epoch [   15/   30] | d_loss: 1.3862 | g_loss: 0.6955
# Epoch [   15/   30] | d_loss: 1.3868 | g_loss: 0.7114
# Epoch [   15/   30] | d_loss: 1.3858 | g_loss: 0.7092
# Epoch [   15/   30] | d_loss: 1.3933 | g_loss: 0.6973
# Epoch [   15/   30] | d_loss: 1.3852 | g_loss: 0.7083
# Epoch [   15/   30] | d_loss: 1.3922 | g_loss: 0.7005
# Epoch [   15/   30] | d_loss: 1.3881 | g_loss: 0.6960
# Epoch [   15/   30] | d_loss: 1.3770 | g_loss: 0.7038
# Epoch [   15/   30] | d_loss: 1.3911 | g_loss: 0.6982
# Epoch [   16/   30] | d_loss: 1.3890 | g_loss: 0.6988
# Epoch [   16/   30] | d_loss: 1.3856 | g_loss: 0.7168
# Epoch [   16/   30] | d_loss: 1.3902 | g_loss: 0.7177
# Epoch [   16/   30] | d_loss: 1.3906 | g_loss: 0.6807
# Epoch [   16/   30] | d_loss: 1.3905 | g_loss: 0.6969
# Epoch [   16/   30] | d_loss: 1.3971 | g_loss: 0.7802
# Epoch [   16/   30] | d_loss: 1.3983 | g_loss: 0.7423
# Epoch [   16/   30] | d_loss: 1.3861 | g_loss: 0.6808
# Epoch [   16/   30] | d_loss: 1.3948 | g_loss: 0.7571
# Epoch [   16/   30] | d_loss: 1.3869 | g_loss: 0.7238
# Epoch [   16/   30] | d_loss: 1.3894 | g_loss: 0.8146
# Epoch [   16/   30] | d_loss: 1.3795 | g_loss: 0.7042
# Epoch [   16/   30] | d_loss: 1.3868 | g_loss: 0.7197
# Epoch [   16/   30] | d_loss: 1.3912 | g_loss: 0.6486
# Epoch [   16/   30] | d_loss: 1.4282 | g_loss: 0.5579
# Epoch [   17/   30] | d_loss: 1.4049 | g_loss: 0.7591
# Epoch [   17/   30] | d_loss: 1.3862 | g_loss: 0.7188
# Epoch [   17/   30] | d_loss: 1.3827 | g_loss: 0.7121
# Epoch [   17/   30] | d_loss: 1.3969 | g_loss: 0.6650
# Epoch [   17/   30] | d_loss: 1.3871 | g_loss: 0.6761
# Epoch [   17/   30] | d_loss: 1.3909 | g_loss: 0.7221
# Epoch [   17/   30] | d_loss: 1.4022 | g_loss: 0.7370
# Epoch [   17/   30] | d_loss: 1.3836 | g_loss: 0.6984
# Epoch [   17/   30] | d_loss: 1.3997 | g_loss: 0.5974
# Epoch [   17/   30] | d_loss: 1.3923 | g_loss: 0.7080
# Epoch [   17/   30] | d_loss: 1.3865 | g_loss: 0.6613
# Epoch [   17/   30] | d_loss: 1.3816 | g_loss: 0.7030
# Epoch [   17/   30] | d_loss: 1.4003 | g_loss: 0.7897
# Epoch [   17/   30] | d_loss: 1.3882 | g_loss: 0.7125
# Epoch [   17/   30] | d_loss: 1.3905 | g_loss: 0.7080
# Epoch [   18/   30] | d_loss: 1.3869 | g_loss: 0.6961
# Epoch [   18/   30] | d_loss: 1.3956 | g_loss: 0.6507
# Epoch [   18/   30] | d_loss: 1.3897 | g_loss: 0.7095
# Epoch [   18/   30] | d_loss: 1.3968 | g_loss: 0.7516
# Epoch [   18/   30] | d_loss: 1.3854 | g_loss: 0.7040
# Epoch [   18/   30] | d_loss: 1.3882 | g_loss: 0.6940
# Epoch [   18/   30] | d_loss: 1.3852 | g_loss: 0.6730
# Epoch [   18/   30] | d_loss: 1.4129 | g_loss: 0.6628
# Epoch [   18/   30] | d_loss: 1.5151 | g_loss: 0.4465
# Epoch [   18/   30] | d_loss: 1.3853 | g_loss: 0.7054
# Epoch [   18/   30] | d_loss: 1.3997 | g_loss: 0.7513
# Epoch [   18/   30] | d_loss: 1.3878 | g_loss: 0.6984
# Epoch [   18/   30] | d_loss: 1.3953 | g_loss: 0.6817
# Epoch [   18/   30] | d_loss: 1.3939 | g_loss: 0.6530
# Epoch [   18/   30] | d_loss: 1.3932 | g_loss: 0.6841
# Epoch [   19/   30] | d_loss: 1.3971 | g_loss: 0.7017
# Epoch [   19/   30] | d_loss: 1.4028 | g_loss: 0.5961
# Epoch [   19/   30] | d_loss: 1.3898 | g_loss: 0.6866
# Epoch [   19/   30] | d_loss: 1.3891 | g_loss: 0.7490
# Epoch [   19/   30] | d_loss: 1.3889 | g_loss: 0.6874
# Epoch [   19/   30] | d_loss: 1.3911 | g_loss: 0.6537
# Epoch [   19/   30] | d_loss: 1.3926 | g_loss: 0.6092
# Epoch [   19/   30] | d_loss: 1.3843 | g_loss: 0.6949
# Epoch [   19/   30] | d_loss: 1.3888 | g_loss: 0.6638
# Epoch [   19/   30] | d_loss: 1.3820 | g_loss: 0.6905
# Epoch [   19/   30] | d_loss: 1.3971 | g_loss: 0.6586
# Epoch [   19/   30] | d_loss: 1.3845 | g_loss: 0.7005
# Epoch [   19/   30] | d_loss: 1.3944 | g_loss: 0.6106
# Epoch [   19/   30] | d_loss: 1.3856 | g_loss: 0.6710
# Epoch [   19/   30] | d_loss: 1.4016 | g_loss: 0.5870
# Epoch [   20/   30] | d_loss: 1.3995 | g_loss: 0.8127
# Epoch [   20/   30] | d_loss: 1.3903 | g_loss: 0.7149
# Epoch [   20/   30] | d_loss: 1.3813 | g_loss: 0.7056
# Epoch [   20/   30] | d_loss: 1.3857 | g_loss: 0.7514
# Epoch [   20/   30] | d_loss: 1.3911 | g_loss: 0.7367
# Epoch [   20/   30] | d_loss: 1.3961 | g_loss: 0.7213
# Epoch [   20/   30] | d_loss: 1.3824 | g_loss: 0.7062
# Epoch [   20/   30] | d_loss: 1.3923 | g_loss: 0.6834
# Epoch [   20/   30] | d_loss: 1.3866 | g_loss: 0.7101
# Epoch [   20/   30] | d_loss: 1.3896 | g_loss: 0.7087
# Epoch [   20/   30] | d_loss: 1.3913 | g_loss: 0.7614
# Epoch [   20/   30] | d_loss: 1.3949 | g_loss: 0.7237
# Epoch [   20/   30] | d_loss: 1.3890 | g_loss: 0.6857
# Epoch [   20/   30] | d_loss: 1.3977 | g_loss: 0.5914
# Epoch [   20/   30] | d_loss: 1.3897 | g_loss: 0.6964
# Epoch [   21/   30] | d_loss: 1.3882 | g_loss: 0.6879
# Epoch [   21/   30] | d_loss: 1.3945 | g_loss: 0.6254
# Epoch [   21/   30] | d_loss: 1.3901 | g_loss: 0.6536
# Epoch [   21/   30] | d_loss: 1.3875 | g_loss: 0.6528
# Epoch [   21/   30] | d_loss: 1.3862 | g_loss: 0.6660
# Epoch [   21/   30] | d_loss: 1.3894 | g_loss: 0.6979
# Epoch [   21/   30] | d_loss: 1.3877 | g_loss: 0.6622
# Epoch [   21/   30] | d_loss: 1.3931 | g_loss: 0.6284
# Epoch [   21/   30] | d_loss: 1.3888 | g_loss: 0.6807
# Epoch [   21/   30] | d_loss: 1.3895 | g_loss: 0.6950
# Epoch [   21/   30] | d_loss: 1.3969 | g_loss: 0.8120
# Epoch [   21/   30] | d_loss: 1.3845 | g_loss: 0.7089
# Epoch [   21/   30] | d_loss: 1.3867 | g_loss: 0.7017
# Epoch [   21/   30] | d_loss: 1.3943 | g_loss: 0.6179
# Epoch [   21/   30] | d_loss: 1.3850 | g_loss: 0.6471
# Epoch [   22/   30] | d_loss: 1.3873 | g_loss: 0.7664
# Epoch [   22/   30] | d_loss: 1.3870 | g_loss: 0.6948
# Epoch [   22/   30] | d_loss: 1.3888 | g_loss: 0.6745
# Epoch [   22/   30] | d_loss: 1.3939 | g_loss: 0.6783
# Epoch [   22/   30] | d_loss: 1.3882 | g_loss: 0.6525
# Epoch [   22/   30] | d_loss: 1.3876 | g_loss: 0.6896
# Epoch [   22/   30] | d_loss: 1.3855 | g_loss: 0.6827
# Epoch [   22/   30] | d_loss: 1.3878 | g_loss: 0.7171
# Epoch [   22/   30] | d_loss: 1.3886 | g_loss: 0.7024
# Epoch [   22/   30] | d_loss: 1.3909 | g_loss: 0.7534
# Epoch [   22/   30] | d_loss: 1.3918 | g_loss: 0.7339
# Epoch [   22/   30] | d_loss: 1.3860 | g_loss: 0.7036
# Epoch [   22/   30] | d_loss: 1.3873 | g_loss: 0.7031
# Epoch [   22/   30] | d_loss: 1.3862 | g_loss: 0.6930
# Epoch [   22/   30] | d_loss: 1.3902 | g_loss: 0.6987
# Epoch [   23/   30] | d_loss: 1.3884 | g_loss: 0.6877
# Epoch [   23/   30] | d_loss: 1.3924 | g_loss: 0.7964
# Epoch [   23/   30] | d_loss: 1.3853 | g_loss: 0.7026
# Epoch [   23/   30] | d_loss: 1.3908 | g_loss: 0.7479
# Epoch [   23/   30] | d_loss: 1.3872 | g_loss: 0.7128
# Epoch [   23/   30] | d_loss: 1.4085 | g_loss: 0.8476
# Epoch [   23/   30] | d_loss: 1.3862 | g_loss: 0.6952
# Epoch [   23/   30] | d_loss: 1.3949 | g_loss: 0.7711
# Epoch [   23/   30] | d_loss: 1.3842 | g_loss: 0.6757
# Epoch [   23/   30] | d_loss: 1.3845 | g_loss: 0.7201
# Epoch [   23/   30] | d_loss: 1.4059 | g_loss: 0.8119
# Epoch [   23/   30] | d_loss: 1.3921 | g_loss: 0.6999
# Epoch [   23/   30] | d_loss: 1.4014 | g_loss: 0.8190
# Epoch [   23/   30] | d_loss: 1.3923 | g_loss: 0.6433
# Epoch [   23/   30] | d_loss: 1.3873 | g_loss: 0.6927
# Epoch [   24/   30] | d_loss: 1.3885 | g_loss: 0.6981
# Epoch [   24/   30] | d_loss: 1.3871 | g_loss: 0.6757
# Epoch [   24/   30] | d_loss: 1.4042 | g_loss: 0.5762
# Epoch [   24/   30] | d_loss: 1.3836 | g_loss: 0.6743
# Epoch [   24/   30] | d_loss: 1.3871 | g_loss: 0.6409
# Epoch [   24/   30] | d_loss: 1.4074 | g_loss: 0.6811
# Epoch [   24/   30] | d_loss: 1.3914 | g_loss: 0.6771
# Epoch [   24/   30] | d_loss: 1.3943 | g_loss: 0.6738
# Epoch [   24/   30] | d_loss: 1.3872 | g_loss: 0.7007
# Epoch [   24/   30] | d_loss: 1.3888 | g_loss: 0.6454
# Epoch [   24/   30] | d_loss: 1.3790 | g_loss: 0.6855
# Epoch [   24/   30] | d_loss: 1.3867 | g_loss: 0.7025
# Epoch [   24/   30] | d_loss: 1.4060 | g_loss: 0.7457
# Epoch [   24/   30] | d_loss: 1.3901 | g_loss: 0.7187
# Epoch [   24/   30] | d_loss: 1.3784 | g_loss: 0.7468
# Epoch [   25/   30] | d_loss: 1.3708 | g_loss: 0.6674
# Epoch [   25/   30] | d_loss: 1.4064 | g_loss: 0.8420
# Epoch [   25/   30] | d_loss: 1.4163 | g_loss: 0.7954
# Epoch [   25/   30] | d_loss: 1.3897 | g_loss: 0.6973
# Epoch [   25/   30] | d_loss: 1.3842 | g_loss: 0.6895
# Epoch [   25/   30] | d_loss: 1.3867 | g_loss: 0.6861
# Epoch [   25/   30] | d_loss: 1.3848 | g_loss: 0.7009
# Epoch [   25/   30] | d_loss: 1.3912 | g_loss: 0.6943
# Epoch [   25/   30] | d_loss: 1.3813 | g_loss: 0.6936
# Epoch [   25/   30] | d_loss: 1.3904 | g_loss: 0.6813
# Epoch [   25/   30] | d_loss: 1.3909 | g_loss: 0.7221
# Epoch [   25/   30] | d_loss: 1.3934 | g_loss: 0.6855
# Epoch [   25/   30] | d_loss: 1.3949 | g_loss: 0.7114
# Epoch [   25/   30] | d_loss: 1.3897 | g_loss: 0.6944
# Epoch [   25/   30] | d_loss: 1.3876 | g_loss: 0.6963
# Epoch [   26/   30] | d_loss: 1.3898 | g_loss: 0.6955
# Epoch [   26/   30] | d_loss: 1.3896 | g_loss: 0.6986
# Epoch [   26/   30] | d_loss: 1.3925 | g_loss: 0.7603
# Epoch [   26/   30] | d_loss: 1.3877 | g_loss: 0.6916
# Epoch [   26/   30] | d_loss: 1.3931 | g_loss: 0.7769
# Epoch [   26/   30] | d_loss: 1.3873 | g_loss: 0.6937
# Epoch [   26/   30] | d_loss: 1.3859 | g_loss: 0.6942
# Epoch [   26/   30] | d_loss: 1.3850 | g_loss: 0.6947
# Epoch [   26/   30] | d_loss: 1.3846 | g_loss: 0.6577
# Epoch [   26/   30] | d_loss: 1.3900 | g_loss: 0.7017
# Epoch [   26/   30] | d_loss: 1.3922 | g_loss: 0.6963
# Epoch [   26/   30] | d_loss: 1.3854 | g_loss: 0.7061
# Epoch [   26/   30] | d_loss: 1.3852 | g_loss: 0.6954
# Epoch [   26/   30] | d_loss: 1.3882 | g_loss: 0.6935
# Epoch [   26/   30] | d_loss: 1.3899 | g_loss: 0.6988
# Epoch [   27/   30] | d_loss: 1.3900 | g_loss: 0.6895
# Epoch [   27/   30] | d_loss: 1.4127 | g_loss: 0.5324
# Epoch [   27/   30] | d_loss: 1.3896 | g_loss: 0.7425
# Epoch [   27/   30] | d_loss: 1.3912 | g_loss: 0.6509
# Epoch [   27/   30] | d_loss: 1.3873 | g_loss: 0.7017
# Epoch [   27/   30] | d_loss: 1.3877 | g_loss: 0.6804
# Epoch [   27/   30] | d_loss: 1.3876 | g_loss: 0.6961
# Epoch [   27/   30] | d_loss: 1.3884 | g_loss: 0.7473
# Epoch [   27/   30] | d_loss: 1.3845 | g_loss: 0.7169
# Epoch [   27/   30] | d_loss: 1.3786 | g_loss: 0.6961
# Epoch [   27/   30] | d_loss: 1.3908 | g_loss: 0.7418
# Epoch [   27/   30] | d_loss: 1.3872 | g_loss: 0.7131
# Epoch [   27/   30] | d_loss: 1.4024 | g_loss: 0.5963
# Epoch [   27/   30] | d_loss: 1.4313 | g_loss: 0.9363
# Epoch [   27/   30] | d_loss: 1.3901 | g_loss: 0.7208
# Epoch [   28/   30] | d_loss: 1.3885 | g_loss: 0.6828
# Epoch [   28/   30] | d_loss: 1.3815 | g_loss: 0.7210
# Epoch [   28/   30] | d_loss: 1.3946 | g_loss: 0.6832
# Epoch [   28/   30] | d_loss: 1.3873 | g_loss: 0.6885
# Epoch [   28/   30] | d_loss: 1.3871 | g_loss: 0.7013
# Epoch [   28/   30] | d_loss: 1.3846 | g_loss: 0.7025
# Epoch [   28/   30] | d_loss: 1.3933 | g_loss: 0.7223
# Epoch [   28/   30] | d_loss: 1.3914 | g_loss: 0.6709
# Epoch [   28/   30] | d_loss: 1.3855 | g_loss: 0.6895
# Epoch [   28/   30] | d_loss: 1.3875 | g_loss: 0.6960
# Epoch [   28/   30] | d_loss: 1.3885 | g_loss: 0.6931
# Epoch [   28/   30] | d_loss: 1.3984 | g_loss: 0.7996
# Epoch [   28/   30] | d_loss: 1.3871 | g_loss: 0.6900
# Epoch [   28/   30] | d_loss: 1.3869 | g_loss: 0.6931
# Epoch [   28/   30] | d_loss: 1.3863 | g_loss: 0.6840
# Epoch [   29/   30] | d_loss: 1.3869 | g_loss: 0.7053
# Epoch [   29/   30] | d_loss: 1.3970 | g_loss: 0.6086
# Epoch [   29/   30] | d_loss: 1.3852 | g_loss: 0.6963
# Epoch [   29/   30] | d_loss: 1.3921 | g_loss: 0.7125
# Epoch [   29/   30] | d_loss: 1.3880 | g_loss: 0.6949
# Epoch [   29/   30] | d_loss: 1.3884 | g_loss: 0.7036
# Epoch [   29/   30] | d_loss: 1.3901 | g_loss: 0.7048
# Epoch [   29/   30] | d_loss: 1.3929 | g_loss: 0.7314
# Epoch [   29/   30] | d_loss: 1.3897 | g_loss: 0.7075
# Epoch [   29/   30] | d_loss: 1.3902 | g_loss: 0.6922
# Epoch [   29/   30] | d_loss: 1.3868 | g_loss: 0.7011
# Epoch [   29/   30] | d_loss: 1.3841 | g_loss: 0.6907
# Epoch [   29/   30] | d_loss: 1.3860 | g_loss: 0.6668
# Epoch [   29/   30] | d_loss: 1.3961 | g_loss: 0.6170
# Epoch [   29/   30] | d_loss: 1.4049 | g_loss: 0.5753
# Epoch [   30/   30] | d_loss: 1.4012 | g_loss: 0.8019
# Epoch [   30/   30] | d_loss: 1.3863 | g_loss: 0.6951
# Epoch [   30/   30] | d_loss: 1.3882 | g_loss: 0.6995
# Epoch [   30/   30] | d_loss: 1.3925 | g_loss: 0.6380
# Epoch [   30/   30] | d_loss: 1.3867 | g_loss: 0.6655
# Epoch [   30/   30] | d_loss: 1.3881 | g_loss: 0.6954
# Epoch [   30/   30] | d_loss: 1.3878 | g_loss: 0.6947
# Epoch [   30/   30] | d_loss: 1.3935 | g_loss: 0.7707
# Epoch [   30/   30] | d_loss: 1.3866 | g_loss: 0.6785
# Epoch [   30/   30] | d_loss: 1.3925 | g_loss: 0.7516
# Epoch [   30/   30] | d_loss: 1.3875 | g_loss: 0.7419
# Epoch [   30/   30] | d_loss: 1.3869 | g_loss: 0.6986
# Epoch [   30/   30] | d_loss: 1.4055 | g_loss: 0.5598
# Epoch [   30/   30] | d_loss: 1.3884 | g_loss: 0.7151
# Epoch [   30/   30] | d_loss: 1.3887 | g_loss: 0.7000

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots(figsize=(10,5))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** (Write your answer in this cell)
#
# Model has generated realistic images. All elements of face and postures look reasonable, except for one or two of sampels. It is slightly biased towards white faces as celebraties are mainly white. Definitely, model peformance would have been much higher with higher resoultion pictures of 64*64 as input.
# However, the loss trends are not converging. Looking into discriminator loss, it appears that after few epochs it has reached quickly to a value close to zero. It is not flat so it is learning but the trend is almsot linear. That could imply that discriminator is not challenged enough. There are some tricks to implement to check if loss trends could be improved.
# * Introduc noise (typicaly Gaussian) to input images to the discriminator
# * Apply a different soft labelling startegy to reduce discriminator confidence more. For example, select a random humber close to 1 instaed of a fixed number of 1. The same can be applied for fake image detection.
# * Even to make it harder on discriminator, use a dropout of let's say 50% in fully connected layer. We could extend that to generator linear layer too.
# * To make it much harder on discriminator,  random label fliping startegy could be used when training discriminator.
# * Different optimization strategy or even optimizers could also be tried. For example, SGD for discriniator and ADAM for generator.

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
